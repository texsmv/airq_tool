# %%
from source.app_dataset import OntarioDataset, BrasilDataset

# %%
dataset = OntarioDataset(granularity='years', cache=True)

# %%
dataset.stations_map
for station in dataset.stations:
    latitude = dataset.stations_map[station]['latitude']
    longitude = dataset.stations_map[station]['longitude']
    # name = dataset.stations_map[station]['name']
    print("'{}': [{}, {}],".format(station, latitude, longitude))
# Out:
# 'Windsor Downtown': [42.315778, -83.043667],
# 'Windsor West': [42.292889, -83.073139],
# 'Chatham': [42.403694, -82.208306],
# 'Sarnia': [42.990263, -82.395341],
# 'Sarnia': [42.990263, -82.395341],
# 'Grand Bend': [43.333083, -81.742889],
# 'London': [42.97446, -81.200858],
# 'London': [42.97446, -81.200858],
# 'Port Stanley': [42.672083, -81.162889],
# 'Tiverton': [44.314472, -81.549722],
# 'Brantford': [43.138611, -80.292639],
# 'Kitchener': [43.443833, -80.503806],
# 'St. Catharines': [43.160056, -79.23475],
# 'Guelph': [43.551611, -80.264167],
# 'Hamilton Downtown': [43.257778, -79.861667],
# 'Hamilton Mountain': [43.24132, -79.88941],
# 'Hamilton West': [43.257444, -79.90775],
# 'Hamilton Mountain': [43.24132, -79.88941],
# 'Toronto Downtown': [43.662972, -79.388111],
# 'Toronto East': [43.747917, -79.274056],
# 'Toronto North': [43.78047, -79.467372],
# 'Toronto North': [43.78047, -79.467372],
# 'Toronto West': [43.709444, -79.5435],
# 'Burlington': [43.315111, -79.802639],
# ...

# %%
dataset.stations_map
# Out:
# {'47045': {'name': 'Barrie',
#   'latitude': '44.382361',
#   'longitude': '-79.702306'},
#  '54012': {'name': 'Belleville',
#   'latitude': '44.150528',
#   'longitude': '-77.3955'},
#  '46089': {'name': 'Brampton',
#   'latitude': '43.69875',
#   'longitude': '-79.780917'},
#  '21005': {'name': 'Brantford',
#   'latitude': '43.138611',
#   'longitude': '-80.292639'},
#  '44008': {'name': 'Burlington',
#   'latitude': '43.315111',
#   'longitude': '-79.802639'},
#  '13001': {'name': 'Chatham',
#   'latitude': '42.403694',
#   'longitude': '-82.208306'},
#  '56051': {'name': 'Cornwall',
#   'latitude': '45.017972',
#   'longitude': '-74.735222'},
#  '49010': {'name': 'Dorset',
#   'latitude': '45.224278',
#   'longitude': '-78.932944'},
#  '15020': {'name': 'Grand Bend',
#   'latitude': '43.333083',
#   'longitude': '-81.742889'},
#  '28028': {'name': 'Guelph',
#   'latitude': '43.551611',
#   'longitude': '-80.264167'},
#  '29000': {'name': 'Hamilton Downtown',
# ...
